# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
import folium

print("Her şey doğru çalışıyor!")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Her şey doğru çalışıyor!

# %%
import os

os.listdir("../data/raw")
# Out:
# ['public_emdat_custom_request_2025-11-22_fc1861af-0c81-43ce-a197-ab678ab7dd06.xlsx',
#  'turkey_earthquakes(1915-2024_feb).csv']

# %%
df_kaggle = pd.read_csv("../data/raw/turkey_earthquakes(1915-2024_feb).csv")
df_kaggle.head()
# Out:
#    No     Deprem Kodu Olus tarihi  Olus zamani    Enlem   Boylam  Derinlik  \
# 0   1  20231231222846  2023.12.31  22:28:46.51  37.4900  43.7095       2.6
# 1   2  20231231170605  2023.12.31  17:06:05.42  37.4405  43.9263       5.0
# 2   3  20231231165304  2023.12.31  16:53:04.13  37.4942  43.6955       5.0
# 3   4  20231231163755  2023.12.31  16:37:55.84  37.4763  43.6965       5.0
# 4   5  20231230204324  2023.12.30  20:43:24.21  40.2272  29.1705      12.9
#
#     xM   MD   ML   Mw   Ms   Mb Tip  \
# 0  3.8  0.0  3.8  3.8  0.0  0.0  Ke
# 1  4.5  0.0  4.5  4.4  0.0  0.0  Ke
# 2  3.5  0.0  3.5  3.4  0.0  0.0  Ke
# 3  4.6  0.0  4.6  4.4  0.0  0.0  Ke
# 4  3.6  0.0  3.6  3.4  0.0  0.0  Ke
#
#                                                Yer
# 0                 BAYKOY- (HAKKARI) [South 6.8 km]
# 1  YAZILI-YUKSEKOVA (HAKKARI) [South West  3.6 km]
# 2                 CIMENLI- (HAKKARI) [East 6.1 km]
# 3          CIMENLI- (HAKKARI) [South East  6.3 km]
# ...

# %%
df_emdat = pd.read_excel("../data/raw/public_emdat_custom_request_2025-11-22_fc1861af-0c81-43ce-a197-ab678ab7dd06.xlsx")
df_emdat.head()
# Out:
#           DisNo. Historic Classification Key Disaster Group Disaster Subgroup  \
# 0  1924-0009-TUR      Yes    nat-geo-ear-gro        Natural       Geophysical
# 1  1924-0011-TUR      Yes    nat-geo-ear-gro        Natural       Geophysical
# 2  1925-0009-TUR      Yes    nat-geo-ear-gro        Natural       Geophysical
# 3  1925-0013-TUR      Yes    nat-geo-ear-gro        Natural       Geophysical
# 4  1928-0005-TUR      Yes    nat-geo-ear-gro        Natural       Geophysical
#
#   Disaster Type Disaster Subtype External IDs  Event Name  ISO  ...  \
# 0    Earthquake  Ground movement          NaN         NaN  TUR  ...
# 1    Earthquake  Ground movement          NaN         NaN  TUR  ...
# 2    Earthquake  Ground movement          NaN         NaN  TUR  ...
# 3    Earthquake  Ground movement          NaN         NaN  TUR  ...
# 4    Earthquake  Ground movement          NaN         NaN  TUR  ...
#
#   Reconstruction Costs ('000 US$) Reconstruction Costs, Adjusted ('000 US$)  \
# ...

# %%
df_kaggle.info()
df_kaggle.describe()

df_emdat.info()
df_emdat.describe()

df_kaggle.isna().sum()
df_emdat.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20307 entries, 0 to 20306
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   No           20307 non-null  int64
#  1   Deprem Kodu  20307 non-null  int64
#  2   Olus tarihi  20307 non-null  object
#  3   Olus zamani  20307 non-null  object
#  4   Enlem        20307 non-null  float64
#  5   Boylam       20307 non-null  float64
#  6   Derinlik     20307 non-null  float64
#  7   xM           20307 non-null  float64
#  8   MD           20307 non-null  float64
#  9   ML           20307 non-null  float64
#  10  Mw           7326 non-null   float64
#  11  Ms           20307 non-null  float64
#  12  Mb           20307 non-null  float64
#  13  Tip          20307 non-null  object
#  14  Yer          20307 non-null  object
# dtypes: float64(9), int64(2), object(4)
# memory usage: 2.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# ...

# %%
df_emdat['Total Deaths'].isna().sum()
# Out:
# np.int64(20)

# %%
df_emdat[df_emdat['Total Deaths'].isna()][['Location', 'Total Deaths']]
# Out:
#                                               Location  Total Deaths
# 49                                     Demirci, Manisa           NaN
# 57                                   Pulumur, Erzincan           NaN
# 58                                 Dursunvey, Anatolia           NaN
# 62                         ERZURUM, KARS, AGRI, ARTVIN           NaN
# 64                                          Aydin area           NaN
# 67                                        Corum-Amasya           NaN
# 69                                  Geyhan, Adana area           NaN
# 73                                            Marmaris           NaN
# 79                                   Osmaniye province           NaN
# 80                                    Erzurum province           NaN
# 83                  Buldan district (Denizli province)           NaN
# 84       Seferihisar, Konak districts (Izmir province)           NaN
# 86     Askale, Ilica, Cat districts (Erzurum province)           NaN
# ...

# %%
df_emdat['No. Homeless'].isna().sum()
# Out:
# np.int64(82)

# %%
df_emdat_clean = df_emdat.dropna(subset=['Total Deaths'])

# %%
df_emdat_clean['Total Deaths'].isna().sum()
# Out:
# np.int64(0)

# %%
df_emdat_clean.shape
# Out:
# (90, 46)

# %%
df_emdat['Magnitude'].min()
# Out:
# np.float64(4.2)
